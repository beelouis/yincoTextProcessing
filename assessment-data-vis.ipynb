# %% [markdown]
# # CO584 Assessment 2 - Data Visualisation in Python
#
# This assessment is worth <b>25%</b> of the final mark for this module. The HTML version of all the Jupyter Notebooks provided for this assessment are in the `logs` subfolder.

# %% [markdown]
# ## Submission Instructions
# You should submit all the code that you will write for this assessment, and all your code should be located in one Jupyter Notebook. You can extend the notebooks that are provided by the module team. Your submission should be clearly labelled at the top of your file with your name, your Kent login, and your Kent ID. You should include any data that you will create for this assessment (e.g. the books that you will download from the Gutenberg project). All the output generated by your programs should be embedded in your Jupyter Notebook whenever possible. All the external files generated by your code must be included as well. For example, if you have to save any plots in external files, include all those files. The marking team will read your notebooks in the first instance with the output that you will provide, but they will also run your code on their machines. For this reason, you should submit all the files that are required to compile all your code.
#
# If necessary, the required packages can be installed using: `pip install -r requirements.txt` or `conda install --file requirements.txt`. If you need to install Anaconda and set up a new virtual environment, you may want to read `project_setup.ipynb` that can be found in the current folder.

# %% [markdown]
# ## Submission Method
#
# Upload all your files to your sub-folder in `/proj/comp5840/assessment2/your_login` in Linux or`\\raptor.kent.ac.uk\proj\comp5840\assessment2\login` in Windows. Note that your **folder will be closed after the deadline**, and you won't be able to submit your work after that.
#
# **Please do not zip your files.** Simply copy all your individual files to the appropriate folder on `raptor`.

# %% [markdown]
# ## Question 1: Structure and Organisation
#
# <b>This question is worth [30 marks].</b>
#
# You will receive 30 marks for a well-structured and well-organised Jupyter Notebook. A single Jupyter Notebook should contain the solutions to all the questions that are contained in this assessment. The following criteria must be followed:
#
# 1. A clear structure of the document with dedicated sections for every question; show clearly where one question ends and where the next question begins
# 2. The questions answered in the order they were specified
# 3. All the input files are submitted, and it is possible to run your entire notebook to reproduce all your outputs
# 4. Both the `ipynb` and HTML versions of your notebook are submitted
# 5. Your notebook is submitted with all the outputs (i.e. notebook's outputs are not cleared before submission)
# 6. All the outputs generated by your code should be embedded in your Jupyter Notebook document whenever possible. If external files are necessary (we know that the scattertext in Question 4 will be an external HTML file), such external files should be accessible via URLs embedded in your notebook. To add a URL to your Jupyter Notebook, you can simply type: `[blue_text](url_here)`. Example URLs are shown in the `scattertext.jpynb` file that is located in the current folder.

# %% [markdown]
# ## Question 2: Interactive Scatterplot
#
# <b>This question is worth [20 marks].</b>
#
# In this question, you will extend the <code>scatterplot_iris.ipynb</code> notebook. Its original version creates only one scatterplot for two Iris variables. The Iris dataset has 4 predictor variables in total, and we would like to explore all of them.
#
# 1. Create scatterplots for all pairs of the predictor variables. You want to compute $4\times4=16$ graphs because evey feature will be used to label both axes.
#
# 2. Your scatterplots should be embedded in the notebook. Do not save these plots in external files.

# %% [markdown]
# ## Question 3: PCA and 2D Visualisation
#
# <b>This question is worth [30 marks].</b>
#
# The <code>pca_iris.ipynb</code> notebook shows how to perform PCA on the Iris dataset, and then how to visualise the Iris data in 2 dimensions defined by the first two principal components. In this question, you will apply PCA to a nutritional dataset that is provided in this file <code>CEqbBq1zDue_nutritional_data_english.xlsx</code>. You could follow the following steps:
#
# 1. Read <code>pca_iris.ipynb</code> and study its Python code, and the output that it produces.
#
# 2. Read the <code>pca_nutritional_stud.ipynb</code> notebook. It shows how to read the nutritional data that you will analyse in this question.
#
# 3. Use the code shown in <code>pca_nutritional_stud.ipynb</code> to replace the Iris data in <code>pca_iris.ipynb</code> with the nutritional data. If this step is successful, your final sctatterplot should show the nutritional data in two dimensions. The final plot should appear in your Jupyter Notebook.

# %% [markdown]
# ## Question 4: Text Visualisation using Scattertext
#
# <b>This question is worth [40 marks].</b>
#
# 1. Read the <code>scattertext.ipynb</code> notebook. Execute it, and analyse the two HTML files that it produces (spoken_fiction.html and two_books_scattertext.html). The second one is large, and it may take a few seconds to load in your web browser.
#
# 2. The second half of the <code>scattertext.ipynb</code> file processes the data that is read from the <code>logs/frequencies.csv</code> file. This file contains the term frequencies computed for two books: "Bothers Karamazov" and "The Murder of Roger Ackroyd". Both books were downloaded in the TXT format from the Gutenberg project. The first column in the file contains the word/term, the second column contains the frequency of the words in the first book, and the third column the frequency of the words in the second book. Your task is to create a similar file for two books of your choice, and then to use the <code>scattertext.ipynb</code> programme to generate a scatterplot. Note that you won't need to change anything in <code>scattertext.ipynb</code>, except for the name of your file with term frequencies (assuming that your file is not named <code>logs/frequencies.csv</code>).
#
#  Firstly, go to https://www.gutenberg.org - this is a repository for out-of-copyright books - and download two books. You may want to pick two that are somehow related. For example, the two used in my example have a murder case. You need the Plain Text UTF-8 file of these books.
#
#  Having the two books of your choice, you will write a Python program that will read both books, and will produce a file similar to <code>logs/frequencies.csv</code> with appropriate frequencies. The <code>cmp_term_frequencies_stud.ipynb</code> shows how you can start the process of extracting frequencies. This is the first part of my program that I used to generate frequencies for "Bothers Karamazov" and "The Murder of Roger Ackroyd". You are encouraged to extend this program.
#
# 3. What to submit for this question?
#    - The original books downloaded from https://www.gutenberg.org
#    - The file with term frequencies that your program will generate
#    - The code that will compute and save the term frequencies to the `CSV` file. This code should appear in your Jupyter Notebook
#    - The HTML files with the scattertext plots generated by the <code>scattertext.ipynb</code> notebook when it is executed on your term-frequency file
#    - All the data/output files submitted for this question should be accessible via URLs placed in your main Jupyter Notebook. Note that `scattertext.ipynb` shows how to create URLs.
#
# [Good luck and have fun!]

# %%
print("\nMarek Grzes and Lisa Bonheme")
from datetime import datetime
print("Last modified: ", datetime.now().strftime("%d/%m/%Y %H:%M:%S") + "\n")
# Out:
# Marek Grzes and Lisa Bonheme
# Last modified:  18/02/2022 20:18:43
